# %%
import pandas as pd

# %%
intersect = pd.read_csv('brasil_top100_intersection.csv', index_col=0)
fla = pd.read_csv('brasil_top100_FLA.csv', index_col=0)
flu = pd.read_csv('brasil_top100_FLU.csv', index_col=0)

pd.set_option('display.max_rows', fla.shape[0]+1)

# %%
intersect.head(100)
# Out:
#                           Palavra  Relevancia
# 0                    scriptbanner   24.011339
# 1                        semtexto   23.755688
# 2                         treeapp   23.170266
# 3                           jtext   20.497690
# 4                         xedcias   20.331370
# 5                 galeriasdefotos   19.577054
# 6                        beneides   17.398764
# 7                        mollerke   16.072498
# 8                        fefumems   15.782673
# 9                          iscamp   15.680669
# 10                           ohya   15.448883
# 11             campinternacionais   15.160894
# 12                        notcias   14.654508
# 13           tragediaembrumadinho   14.635092
# 14           noticiaseinformações   14.635092
# 15                       sobotoms   14.562505
# 16                      botonista   14.540008
# 17                  campregionais   14.111663
# 18                        froener   13.419775
# ...

# %%
fla
# Out:
#                                               Palavra  Relevancia
# 0                                           gametimes   21.020910
# 1                                            robaresi   20.716859
# 2                                              oppnus   19.541816
# 3                                         symphysodon   19.416446
# 4                                               “http   19.346506
# 5                                         naoacredito   19.287707
# 6                                          roncaronca   19.210999
# 7                                        ecxhmmessage   19.173410
# 8                                       externalclass   18.937600
# 9                                              ciagym   18.516286
# 10                                       ondehospedar   18.333391
# 11                                        crenicichla   18.177084
# 12                                       apistogramma   18.073452
# ...

# %%
flu
# Out:
#               Palavra  Relevancia
# 0            balreira   19.903204
# 1              aenfer   19.767025
# 2          roncaronca   19.340295
# 3             acciona   18.597569
# 4             chouest   18.585514
# 5          mineroduto   18.310281
# 6           facínoras   17.995329
# 7             ecbahia   17.833580
# 8               bière   17.538001
# 9    esmaltespretagil   17.478684
# 10      penduricários   17.378839
# 11            technip   17.365973
# 12      prevaricando”   17.314736
# 13        jornalhorah   17.292833
# 14           crápulas   17.199483
# 15        brasileirao   17.082580
# 16              pmsjb   17.076901
# 17           bozonaro   17.075106
# 18            neuwied   17.021142
# 19            dataint   16.972950
# 20           soffiati   16.958615
# 21              goyta   16.949956
# 22           telhaton   16.912983
# 23               wied   16.848744
# 24       carnificinas   16.831353
# 25  essenzacosmeticos   16.754483
# ...
